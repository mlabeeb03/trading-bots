# %%
pip install ccxt

# %%
from binance.cm_futures import RequestClient
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-9-7a033982961d> in <module>
# ----> 1 from binance.cm_futures import RequestClient
#
# ImportError: cannot import name 'RequestClient' from 'binance.cm_futures' (/usr/local/lib/python3.8/dist-packages/binance/cm_futures/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
request_client = RequestClient('2b4cf2d7bdc14b23dbcc135c2016fdd9417bffbe9aff5bd4bf0a2d9e02ecc883', 'f98871678c33f086c0decfc84d5e0ed96c83ab1155cc2cbf6dcc56f23b546a8d')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-eb3b82043f36> in <module>
# ----> 1 request_client = RequestClient('2b4cf2d7bdc14b23dbcc135c2016fdd9417bffbe9aff5bd4bf0a2d9e02ecc883', 'f98871678c33f086c0decfc84d5e0ed96c83ab1155cc2cbf6dcc56f23b546a8d')
#
# NameError: name 'RequestClient' is not defined

# %%
result = request_client.get_mark_price(symbol="ETHUSDT")

print("======= Mark Price =======")
PrintBasic.print_obj(result)
print("==========================")
